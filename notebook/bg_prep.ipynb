# %%
from pyspark.sql.functions import regexp_replace
from pyspark.sql.functions import concat, col, lit, to_timestamp, to_date, hour

print("Setup complete")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Setup complete
# </div>

# %%
df_traffic = spark.read.option("header","true").csv("/FileStore/tables/2015_2020.csv").drop('_c0')
df_traffic = df_traffic.filter(df_traffic["1"]=='BEOGRAD')
df_traffic = df_traffic.select(col("0").alias("id"),col("1").alias("city"),col("2").alias("municipality")\
                               ,col("3").alias("timestamp"),col("4").alias("latitude"),col("5").alias("longitude")\
                              ,col("6").alias("outcome"),col("7").alias("participants"),col("8").alias("description"))
display(df_traffic)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>city</th><th>municipality</th><th>timestamp</th><th>latitude</th><th>longitude</th><th>outcome</th><th>participants</th><th>description</th></tr></thead><tbody><tr><td>1106801</td><td>BEOGRAD</td><td>BARAJEVO</td><td>01.10.2015,12:05</td><td>20.4180857555</td><td>44.5788977355</td><td>Sa mat.stetom</td><td>SN SA JEDNIM VOZILOM</td><td>Nezgode sa učešćem jednog vozila i preprekama na ili iznad kolovoza</td></tr><tr><td>1106289</td><td>BEOGRAD</td><td>BARAJEVO</td><td>03.10.2015,12:00</td><td>20.4134764628</td><td>44.5927879951</td><td>Sa povredjenim</td><td>SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA</td><td>Najmanje dva vozila koja se kreću u istom smeru – sustizanje</td></tr><tr><td>1106903</td><td>BEOGRAD</td><td>BARAJEVO</td><td>08.10.2015,20:00</td><td>20.3885608869</td><td>44.5544174799</td><td>Sa mat.stetom</td><td>SN SA JEDNIM VOZILOM</td><td>Nezgoda sa jednim vozilom – silazak sa kolovoza u krivini</td></tr><tr><td>1106338</td><td>BEOGRAD</td><td>BARAJEVO</td><td>11.10.2015,20:40</td><td>20.4472969411</td><td>44.6445427093</td><td>Sa mat.stetom</td><td>SN SA JEDNIM VOZILOM</td><td>Nezgode sa učešćem jednog vozila i preprekama na ili iznad kolovoza</td></tr><tr><td>1106747</td><td>BEOGRAD</td><td>BARAJEVO</td><td>14.10.2015,19:10</td><td>20.412899</td><td>44.577052</td><td>Sa mat.stetom</td><td>SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA</td><td>Ostale nezgode sa učešćem najmanje dva vozila bez skretanja (bez podataka o smeru)</td></tr><tr><td>1106725</td><td>BEOGRAD</td><td>BARAJEVO</td><td>14.10.2015,19:15</td><td>20.437784</td><td>44.646534</td><td>Sa mat.stetom</td><td>SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA</td><td>Ostale nezgode sa učešćem najmanje dva vozila bez skretanja (bez podataka o smeru)</td></tr><tr><td>1106421</td><td>BEOGRAD</td><td>BARAJEVO</td><td>17.10.2015,20:30</td><td>20.308034</td><td>44.593901</td><td>Sa mat.stetom</td><td>SN SA PARKIRANIM VOZILIMA</td><td>Sudar sa parkiranim vozilom sa desne strane kolovoza</td></tr><tr><td>1107460</td><td>BEOGRAD</td><td>BARAJEVO</td><td>17.10.2015,12:00</td><td>20.31733</td><td>44.577778</td><td>Sa mat.stetom</td><td>SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA</td><td>Najmanje dva vozila koja se kreću u istom smeru – preticanje</td></tr><tr><td>1107463</td><td>BEOGRAD</td><td>BARAJEVO</td><td>25.10.2015,16:30</td><td>20.2964159473</td><td>44.5908153184</td><td>Sa mat.stetom</td><td>SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA</td><td>Ostale nezgode sa najmanje dva vozila – suprotni smerovi bez skretanja</td></tr><tr><td>1108118</td><td>BEOGRAD</td><td>BARAJEVO</td><td>25.10.2015,01:20</td><td>20.4099177149</td><td>44.618464171</td><td>Sa povredjenim</td><td>SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA</td><td>Najmanje dva vozila koja se kreću u istom smeru – sustizanje</td></tr><tr><td>1107333</td><td>BEOGRAD</td><td>BARAJEVO</td><td>26.10.2015,17:05</td><td>20.4159264803</td><td>44.5782387699</td><td>Sa mat.stetom</td><td>SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA</td><td>Ostali sudari sa najmanje dva vozila koja se kreću u istom smeru – ostalo</td></tr><tr><td>1109057</td><td>BEOGRAD</td><td>BARAJEVO</td><td>06.11.2015,23:30</td><td>20.4157106825</td><td>44.5809376233</td><td>Sa mat.stetom</td><td>SN SA PARKIRANIM VOZILIMA</td><td>Sudar sa parkiranim vozilom sa desne strane kolovoza</td></tr><tr><td>1109319</td><td>BEOGRAD</td><td>BARAJEVO</td><td>07.11.2015,20:20</td><td>20.4566279702</td><td>44.6388634507</td><td>Sa mat.stetom</td><td>SN SA JEDNIM VOZILOM</td><td>Nezgode sa učešćem jednog vozila i preprekama na ili iznad kolovoza</td></tr><tr><td>1109827</td><td>BEOGRAD</td><td>BARAJEVO</td><td>08.11.2015,09:30</td><td>20.4172753857</td><td>44.5654208396</td><td>Sa mat.stetom</td><td>SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK</td><td>Najmanje dva vozila koja se kreću istim putem u istom smeru uz skretanje, skretanje ulevo ispred d ...

# %%
replaces = [("Sa poginulim","death"),("Sa povredjenim","injury"),("Sa mat.stetom","damage")]
for exp,replace_exp in replaces:
  df_traffic = df_traffic.withColumn("outcome",regexp_replace(col("outcome"),exp,replace_exp).alias("outcome"))

display(df_traffic.select("outcome").distinct())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>outcome</th></tr></thead><tbody><tr><td>death</td></tr><tr><td>injury</td></tr><tr><td>damage</td></tr></tbody></table></div>

# %%
replaces = [("PARK","parked vehicle"),("NAJMANjE DVA","two or more vehicles"),("JEDNIM","one vehicle"),("ACIMA","pedestrian")]
for exp,replace_exp in replaces:
  exp = ".*("+exp+").*"
  df_traffic = df_traffic.withColumn("participants",regexp_replace(col("participants"),exp,replace_exp).alias("participants"))

display(df_traffic.select("participants").distinct())
df_traffic.show(5)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>participants</th></tr></thead><tbody><tr><td>pedestrian</td></tr><tr><td>one vehicle</td></tr><tr><td>parked vehicle</td></tr><tr><td>two or more vehicles</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+------------+----------------+-------------+-------------+-------+--------------------+--------------------+
#      id|   city|municipality|       timestamp|     latitude|    longitude|outcome|        participants|         description|
# +-------+-------+------------+----------------+-------------+-------------+-------+--------------------+--------------------+
# 1106801|BEOGRAD|    BARAJEVO|01.10.2015,12:05|20.4180857555|44.5788977355| damage|         one vehicle|Nezgode sa učešće...|
# 1106289|BEOGRAD|    BARAJEVO|03.10.2015,12:00|20.4134764628|44.5927879951| injury|two or more vehicles|Najmanje dva vozi...|
# 1106903|BEOGRAD|    BARAJEVO|08.10.2015,20:00|20.3885608869|44.5544174799| damage|         one vehicle|Nezgoda sa jednim...|
# 1106338|BEOGRAD|    BARAJEVO|11.10.2015,20:40|20.4472969411|44.6445427093| damage|         one vehicle|Nezgode sa učešće...|
# 1106747|BEOGRAD|    BARAJEVO|14.10.2015,19:10|    20.412899|    44.577052| damage|two or more vehicles|Ostale nezgode sa...|
# +-------+-------+------------+----------------+-------------+-------------+-------+--------------------+--------------------+
# only showing top 5 rows
#
# </div>

# %%
df_traffic = df_traffic.withColumn("timestamp", to_timestamp(df_traffic.timestamp, 'dd.MM.yyyy,HH:mm'))
df_traffic = df_traffic.withColumn("latitude", col("latitude").cast("double"))
df_traffic = df_traffic.withColumn("longitude", col("longitude").cast("double"))
df_traffic.printSchema()
df_traffic.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- id: string (nullable = true)
# -- city: string (nullable = true)
# -- municipality: string (nullable = true)
# -- timestamp: timestamp (nullable = true)
# -- latitude: double (nullable = true)
# -- longitude: double (nullable = true)
# -- outcome: string (nullable = true)
# -- participants: string (nullable = true)
# -- description: string (nullable = true)
#
# +-------+-------+------------+-------------------+-------------+-------------+-------+--------------------+--------------------+
#      id|   city|municipality|          timestamp|     latitude|    longitude|outcome|        participants|         description|
# +-------+-------+------------+-------------------+-------------+-------------+-------+--------------------+--------------------+
# 1106801|BEOGRAD|    BARAJEVO|2015-10-01 12:05:00|20.4180857555|44.5788977355| damage|         one vehicle|Nezgode sa učešće...|
# 1106289|BEOGRAD|    BARAJEVO|2015-10-03 12:00:00|20.4134764628|44.5927879951| injury|two or more vehicles|Najmanje dva vozi...|
# 1106903|BEOGRAD|    BARAJEVO|2015-10-08 20:00:00|20.3885608869|44.5544174799| damage|         one vehicle|Nezgoda sa jednim...|
# 1106338|BEOGRAD|    BARAJEVO|2015-10-11 20:40:00|20.4472969411|44.6445427093| damage|         one vehicle|Nezgode sa učešće...|
# 1106747|BEOGRAD|    BARAJEVO|2015-10-14 19:10:00|    20.412899|    44.577052| damage|two or more vehicles|Ostale nezgode sa...|
# +-------+-------+------------+-------------------+-------------+-------------+-------+--------------------+--------------------+
# only showing top 5 rows
#
# </div>

# %%
df_traffic.registerTempTable("accidents")
df_traffic = spark.sql("""select id, city, municipality, timestamp,
                  case
                    when hour(timestamp)>=4 and hour(timestamp)<7 then "early morning"
                    when hour(timestamp)>=7 and hour(timestamp)<11 then "morning"
                    when hour(timestamp)>=11 and hour(timestamp)<14 then "midday"
                    when hour(timestamp)>=14 and hour(timestamp)<18 then "afternoon"
                    when hour(timestamp)>=18 and hour(timestamp)<20 then "early evening"
                    when hour(timestamp)>=20 and hour(timestamp)<23 then "evening"
                    when hour(timestamp)>=23 or hour(timestamp)<1 then "midnight"
                    else "after midnight"
                  end as day_time,
                  latitude, longitude, outcome, participants, description
                  from accidents """)
df_traffic.registerTempTable("accidents")
df_traffic.show(10)
df_traffic.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+------------+-------------------+--------------+-------------+-------------+-------+--------------------+--------------------+
#      id|   city|municipality|          timestamp|      day_time|     latitude|    longitude|outcome|        participants|         description|
# +-------+-------+------------+-------------------+--------------+-------------+-------------+-------+--------------------+--------------------+
# 1106801|BEOGRAD|    BARAJEVO|2015-10-01 12:05:00|        midday|20.4180857555|44.5788977355| damage|         one vehicle|Nezgode sa učešće...|
# 1106289|BEOGRAD|    BARAJEVO|2015-10-03 12:00:00|        midday|20.4134764628|44.5927879951| injury|two or more vehicles|Najmanje dva vozi...|
# 1106903|BEOGRAD|    BARAJEVO|2015-10-08 20:00:00|       evening|20.3885608869|44.5544174799| damage|         one vehicle|Nezgoda sa jednim...|
# 1106338|BEOGRAD|    BARAJEVO|2015-10-11 20:40:00|       evening|20.4472969411|44.6445427093| damage|         one vehicle|Nezgode sa učešće...|
# 1106747|BEOGRAD|    BARAJEVO|2015-10-14 19:10:00| early evening|    20.412899|    44.577052| damage|two or more vehicles|Ostale nezgode sa...|
# 1106725|BEOGRAD|    BARAJEVO|2015-10-14 19:15:00| early evening|    20.437784|    44.646534| damage|two or more vehicles|Ostale nezgode sa...|
# 1106421|BEOGRAD|    BARAJEVO|2015-10-17 20:30:00|       evening|    20.308034|    44.593901| damage|      parked vehicle|Sudar sa parkiran...|
# 1107460|BEOGRAD|    BARAJEVO|2015-10-17 12:00:00|        midday|     20.31733|    44.577778| damage|two or more vehicles|Najmanje dva vozi...|
# 1107463|BEOGRAD|    BARAJEVO|2015-10-25 16:30:00|     afternoon|20.2964159473|44.5908153184| damage|two or more vehicles|Ostale nezgode sa...|
# 1108118|BEOGRAD|    BARAJEVO|2015-10-25 01:20:00|after midnight|20.4099177149| 44.618464171| injury|two or more vehicles|Najmanje dva vozi...|
# +-------+-------+------------+-------------------+--------------+-------------+-------------+-------+--------------------+--------------------+
# only showing top 10 rows
#
# root
# -- id: string (nullable = true)
# -- city: string (nullable = true)
# -- municipality: string (nullable = true)
# -- timestamp: timestamp (nullable = true)
# -- day_time: string (nullable = false)
# -- latitude: double (nullable = true)
# -- longitude: double (nullable = true)
# -- outcome: string (nullable = true)
# -- participants: string (nullable = true)
# -- description: string (nullable = true)
#
# </div>

# %%
df_summary = spark.read.format('csv').option('header','true').load('/FileStore/tables/sum.csv')
df_observations = spark.read.format('csv').option('header','true').load('/FileStore/tables/obs.csv')

df_summary.printSchema()
df_observations.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: string (nullable = true)
# -- date: string (nullable = true)
# -- high temp: string (nullable = true)
# -- high temp historic: string (nullable = true)
# -- low temp: string (nullable = true)
# -- low temp historic: string (nullable = true)
# -- average: string (nullable = true)
# -- average historic: string (nullable = true)
# -- precipitation: string (nullable = true)
# -- precipitation historic: string (nullable = true)
# -- max wind: string (nullable = true)
# -- max wind historic: string (nullable = true)
# -- pressure: string (nullable = true)
# -- pressure historic: string (nullable = true)
# -- sunrise: string (nullable = true)
# -- sunset: string (nullable = true)
#
# root
# -- _c0: string (nullable = true)
# -- date: string (nullable = true)
# -- time: string (nullable = true)
# -- temperature: string (nullable = true)
# -- humidity: string (nullable = true)
# -- wind: string (nullable = true)
# -- pressure: string (nullable = true)
# -- precipitation: string (nullable = true)
# -- condition: string (nullable = true)
# -- timestamp: string (nullable = true)
#
# </div>

# %%
df_summary = df_summary.withColumn('date', to_date(df_summary.date)).drop('_c0').distinct()
  
spark.sql("set spark.sql.legacy.timeParserPolicy=LEGACY")
df_observations = df_observations.select(to_timestamp(col('timestamp')).alias('timestamp')\
                                                                 ,col('temperature'),col('humidity'),col('wind'),col('pressure'),col('condition'))

df_observations.show(5)
df_summary.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+-----------+--------+----+--------+---------+
#           timestamp|temperature|humidity|wind|pressure|condition|
# +-------------------+-----------+--------+----+--------+---------+
# 2015-01-01 00:00:00|          9|      85|   5|   30.29|     Mist|
# 2015-01-01 00:30:00|          9|      85|   5|   30.29|     Mist|
# 2015-01-01 01:00:00|          9|      85|   5|   30.29|     Mist|
# 2015-01-01 01:30:00|          9|      85|   6|   30.29|     Mist|
# 2015-01-01 02:00:00|          9|      85|   5|   30.29|     Mist|
# +-------------------+-----------+--------+----+--------+---------+
# only showing top 5 rows
#
# +----------+---------+------------------+--------+-----------------+-------+----------------+-------------+----------------------+--------+-----------------+--------+-----------------+-------+------+
#       date|high temp|high temp historic|low temp|low temp historic|average|average historic|precipitation|precipitation historic|max wind|max wind historic|pressure|pressure historic|sunrise|sunset|
# +----------+---------+------------------+--------+-----------------+-------+----------------+-------------+----------------------+--------+-----------------+--------+-----------------+-------+------+
# 2015-01-06|       34|              38.6|      25|             28.4|  31.04|              33|          0.0|                   0.1|      20|                -|   30.03|                -|  07:17| 16:13|
# 2015-01-02|       32|              39.0|      21|             28.8|  26.58|              34|          0.0|                   0.1|       8|                -|   30.26|                -|  07:17| 16:09|
# 2015-01-01|       21|              39.1|       7|             28.9|  13.88|              34|          0.0|                   0.1|       8|                -|   30.29|                -|  07:17| 16:09|
# 2015-01-03|       43|              38.9|      28|             28.7|  35.21|              33|          0.0|                   0.1|      12|                -|   30.09|                -|  07:17| 16:10|
# 2015-01-05|       37|              38.7|      30|             28.5|  33.69|              33|          0.0|                   0.1|      20|                -|   29.91|                -|  07:17| 16:12|
# +----------+---------+------------------+--------+-----------------+-------+----------------+-------------+----------------------+--------+-----------------+--------+-----------------+-------+------+
# only showing top 5 rows
#
# </div>

# %%
df = df_observations
df = df.select(df.timestamp, df.temperature.cast("double"),df.humidity.cast("double"),df.pressure.cast("double"),df.condition)
df.show(3)
df_observations = df

df = df_summary
df = df.select(df.date, df['high temp'].cast("double"),df['high temp historic'].cast("double"),\
               df['low temp'].cast("double"),df['low temp historic'].cast("double"),df['average'].cast("double"),\
               df['average historic'].cast("double"),df['max wind'].cast("double"),df['pressure'].cast("double"),df.sunrise,df.sunset)
df = df.select(df.date, df['high temp'].alias('high'), df['high temp historic'].alias('high_historic'), df['low temp'].alias('low'),\
              df['low temp historic'].alias('low_historic'), df.average, df['average historic'].alias('average_historic'),\
               df['max wind'].alias('max_wind'), df.pressure,df.sunrise,df.sunset)
df.show(3)
df_summary = df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+-----------+--------+--------+---------+
#           timestamp|temperature|humidity|pressure|condition|
# +-------------------+-----------+--------+--------+---------+
# 2015-01-01 00:00:00|        9.0|    85.0|   30.29|     Mist|
# 2015-01-01 00:30:00|        9.0|    85.0|   30.29|     Mist|
# 2015-01-01 01:00:00|        9.0|    85.0|   30.29|     Mist|
# +-------------------+-----------+--------+--------+---------+
# only showing top 3 rows
#
# +----------+----+-------------+----+------------+-------+----------------+--------+--------+-------+------+
#       date|high|high_historic| low|low_historic|average|average_historic|max_wind|pressure|sunrise|sunset|
# +----------+----+-------------+----+------------+-------+----------------+--------+--------+-------+------+
# 2015-01-02|32.0|         39.0|21.0|        28.8|  26.58|            34.0|     8.0|   30.26|  07:17| 16:09|
# 2015-01-01|21.0|         39.1| 7.0|        28.9|  13.88|            34.0|     8.0|   30.29|  07:17| 16:09|
# 2015-01-03|43.0|         38.9|28.0|        28.7|  35.21|            33.0|    12.0|   30.09|  07:17| 16:10|
# +----------+----+-------------+----+------------+-------+----------------+--------+--------+-------+------+
# only showing top 3 rows
#
# </div>

# %%
df_summary.registerTempTable("summary")
df_observations.registerTempTable("observations")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
drop table acc_obs;
create table acc_obs
select a.id, a.municipality, a.timestamp as accident, a.day_time, a.latitude, a.longitude, a.participants, a.outcome, w.timestamp as observation, w.condition, w.temperature, w.humidity, w.pressure
from accidents as a
inner join observations as w
on (date(a.timestamp)=date(w.timestamp) and (
(hour(a.timestamp)=hour(w.timestamp) and (
(hour(a.timestamp)=23 and minute(a.timestamp)>=30 and minute(w.timestamp)>=30) or
(minute(a.timestamp)<=15 and minute(w.timestamp)<=15) or 
(minute(a.timestamp)>15 and minute(a.timestamp)<45 and minute(w.timestamp)>15 and minute(w.timestamp)<45))) or
(minute(a.timestamp)>=45 and minute(w.timestamp)<15 and hour(w.timestamp)-hour(a.timestamp)=1)))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %scala
import com.mongodb.spark._
import spark.implicits._
import org.apache.spark.sql.functions._

val df_a = table("accidents")
val df_s = table("summary")
val df_o = table("observations")
val df_ao = table("acc_obs")
df_a.write.format("com.mongodb.spark.sql.DefaultSource").mode("overwrite").option("database", "belgrade_15-20").option("collection", "accidents").save()
df_s.write.format("com.mongodb.spark.sql.DefaultSource").mode("overwrite").option("database", "belgrade_15-20").option("collection", "summary").save()
df_o.write.format("com.mongodb.spark.sql.DefaultSource").mode("overwrite").option("database", "belgrade_15-20").option("collection", "observations").save()
df_ao.write.format("com.mongodb.spark.sql.DefaultSource").mode("overwrite").option("database", "belgrade_15-20").option("collection", "accidents_observations").save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">import com.mongodb.spark._
# import spark.implicits._
# import org.apache.spark.sql.functions._
# df_a: org.apache.spark.sql.DataFrame = [id: string, city: string ... 8 more fields]
# df_s: org.apache.spark.sql.DataFrame = [date: date, high: double ... 9 more fields]
# df_o: org.apache.spark.sql.DataFrame = [timestamp: timestamp, temperature: double ... 3 more fields]
# df_ao: org.apache.spark.sql.DataFrame = [id: string, municipality: string ... 11 more fields]
# </div>
